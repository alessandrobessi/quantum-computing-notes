# %%
import math
import cmath
import numpy as np
from quantum import quantum

# %% [markdown]
# # 5 - Visualize a Qubit on the Bloch Sphere

# %%
#  |q⟩ = a|0⟩ + b|1⟩ 
# where a = 1/sqrt(2) and b = 1/sqrt(2)

a = 0 #1 / math.sqrt(2)
b = 1 #1 / math.sqrt(2)

q = a * quantum.Zero + b * quantum.One
quantum.info(q, "|q⟩ = a|0⟩ + b|1⟩ ")
# Out:
# |q⟩ = a|0⟩ + b|1⟩
# shape: (2, 1)
# [[0.+0.j]
#  [1.+0.j]]

# %%
q = quantum.Plus
a, b = quantum.get_coefficients(q)
a, b
# Out:
# ((0.7071067811865475+0j), (0.7071067811865475+0j))

# %%
theta, phi = quantum.get_polar_coordinates(q)
theta, phi
# Out:
# (1.5707963267948966, 0.0)

# %%
x, y, z = quantum.get_cartesian_coordinates(q)
x, y, z
# Out:
# (1.0, 1.0, 6.123233995736766e-17)

# %%
quantum.draw_bloch_sphere(q)
